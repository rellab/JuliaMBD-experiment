# %%
using Plots
using DifferentialEquations
using JuliaMBD
using JuliaMBD.Diagram

# %%
@model pitch_rate begin
    @parameter begin
        I_ENG2Fr_ENG_mount = 0
        I_ENG2Rr_ENG_mount = -0.4
        i_center_ENG = 100 #ここで指定しなくてもいいが、パラメーターとして認識されない(現在は初期値)
    end
    @xmlmodel("oldMETI_Vertical_Vibration.drawio", "pitch_rate") #シート名も指定して
end

#warningが出るなら繋がっていないポートがある(addブロックなどで使わないポートを削除すればでない)
# Out:
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in2", "id" => "2U-L9Cm2FjKEAc_njuAr-42", "parent" => "2U-L9Cm2FjKEAc_njuAr-39", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in2", "id" => "2U-L9Cm2FjKEAc_njuAr-34", "parent" => "2U-L9Cm2FjKEAc_njuAr-31", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-28", "parent" => "2U-L9Cm2FjKEAc_njuAr-27", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in1", "id" => "2U-L9Cm2FjKEAc_njuAr-29", "parent" => "2U-L9Cm2FjKEAc_njuAr-27", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in2", "id" => "2U-L9Cm2FjKEAc_njuAr-50", "parent" => "2U-L9Cm2FjKEAc_njuAr-47", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-44", "parent" => "2U-L9Cm2FjKEAc_njuAr-43", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in1", "id" => "2U-L9Cm2FjKEAc_njuAr-45", "parent" => "2U-L9Cm2FjKEAc_njuAr-43", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in1", "id" => "2U-L9Cm2FjKEAc_njuAr-53", "parent" => "2U-L9Cm2FjKEAc_njuAr-51", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-52", "parent" => "2U-L9Cm2FjKEAc_njuAr-51", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-12", "parent" => "2U-L9Cm2FjKEAc_njuAr-11", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-14", "parent" => "2U-L9Cm2FjKEAc_njuAr-13", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-16", "parent" => "2U-L9Cm2FjKEAc_njuAr-15", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-24", "parent" => "2U-L9Cm2FjKEAc_njuAr-23", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-2", "parent" => "2U-L9Cm2FjKEAc_njuAr-1", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-10", "parent" => "2U-L9Cm2FjKEAc_njuAr-9", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in1", "id" => "2U-L9Cm2FjKEAc_njuAr-49", "parent" => "2U-L9Cm2FjKEAc_njuAr-47", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in2", "id" => "2U-L9Cm2FjKEAc_njuAr-54", "parent" => "2U-L9Cm2FjKEAc_njuAr-51", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-36", "parent" => "2U-L9Cm2FjKEAc_njuAr-35", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-18", "parent" => "2U-L9Cm2FjKEAc_njuAr-17", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-6", "parent" => "2U-L9Cm2FjKEAc_njuAr-5", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in2", "id" => "2U-L9Cm2FjKEAc_njuAr-38", "parent" => "2U-L9Cm2FjKEAc_njuAr-35", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-48", "parent" => "2U-L9Cm2FjKEAc_njuAr-47", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in2", "id" => "2U-L9Cm2FjKEAc_njuAr-46", "parent" => "2U-L9Cm2FjKEAc_njuAr-43", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-8", "parent" => "2U-L9Cm2FjKEAc_njuAr-7", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-32", "parent" => "2U-L9Cm2FjKEAc_njuAr-31", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in2", "id" => "2U-L9Cm2FjKEAc_njuAr-30", "parent" => "2U-L9Cm2FjKEAc_njuAr-27", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in3", "id" => "2U-L9Cm2FjKEAc_njuAr-55", "parent" => "2U-L9Cm2FjKEAc_njuAr-51", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-40", "parent" => "2U-L9Cm2FjKEAc_njuAr-39", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-20", "parent" => "2U-L9Cm2FjKEAc_njuAr-19", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in4", "id" => "2U-L9Cm2FjKEAc_njuAr-56", "parent" => "2U-L9Cm2FjKEAc_njuAr-51", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in1", "id" => "2U-L9Cm2FjKEAc_njuAr-41", "parent" => "2U-L9Cm2FjKEAc_njuAr-39", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-26", "parent" => "2U-L9Cm2FjKEAc_njuAr-25", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-4", "parent" => "2U-L9Cm2FjKEAc_njuAr-3", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in1", "id" => "2U-L9Cm2FjKEAc_njuAr-33", "parent" => "2U-L9Cm2FjKEAc_njuAr-31", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "out", "id" => "2U-L9Cm2FjKEAc_njuAr-22", "parent" => "2U-L9Cm2FjKEAc_njuAr-21", "type" => "outport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in1", "id" => "2U-L9Cm2FjKEAc_njuAr-37", "parent" => "2U-L9Cm2FjKEAc_njuAr-35", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# ┌ Warning: Duplicate block name in
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:100
# ┌ Warning: Duplicate block name in
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:100
# ┌ Warning: Duplicate block name in
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:100
# ┌ Warning: Duplicate block name in
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:100
# ┌ Warning: Duplicate block name in
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:100
# pitch_rate (generic function with 1 method)

# %%
@model Test_pitch_rate begin

    @block begin
        p = pitch_rate()
        ramp1 = Ramp(starttime=10, slope=5)
        ramp2 = Ramp(starttime=10, slope=15)
    end
    @connect begin
        ramp1.out => p.in1  #in1のポート名を変えたのならその名前にしないといけない(p.F_ENG_MNT_F2ENG_N)
        ramp2.out => p.in2
    end
    @scope begin
        p.in1 => inin1  #(p.F_ENG_MNT_F2ENG_N)
        p.in2 => inin2
        p.out1 => outout1 #(p.omg_ENG_pitch_rate_radps)
    end
end

#m = @compile Test_pitch_rate()  #i_center_ENG = 1000 モデルを作成するときに値を決めることもできる(書き換える)
m = @compile Test_pitch_rate()
res = simulate(m, tspan=[0, 100])
plot(res)
# Out:
# UndefVarError: `value` not defined
#
#
#
# Stacktrace:
#
#  [1] macro expansion
#
#    @ ~/.julia/packages/JuliaMBD/3ZWy5/src/_macro.jl:95 [inlined]
#
#  [2] macro expansion
#
#    @ ./none:8 [inlined]
#
#  [3] pitch_rate(; I_ENG2Fr_ENG_mount::Int64, I_ENG2Rr_ENG_mount::Float64, i_center_ENG::Int64)
#
#    @ Main /workspaces/JuliaMBD-sample/OldMETI_Vertical_Vibration.ipynb:159
#
#  [4] pitch_rate
#
#    @ ./none:0 [inlined]
#
#  [5] macro expansion
#
#    @ ~/.julia/packages/JuliaMBD/3ZWy5/src/_macro.jl:95 [inlined]
#
#  [6] Test_pitch_rate()
#
#    @ Main /workspaces/JuliaMBD-sample/OldMETI_Vertical_Vibration.ipynb:4
#
#  [7] top-level scope
#
#    @ ~/.julia/packages/JuliaMBD/3ZWy5/src/_ode.jl:9

# %%
@model v_z_carbody begin
    @parameter begin
        M_ENG = 50
        g = 9.8
    end
    @xmlmodel("oldMETI_Vertical_Vibration.drawio", "v_z_carbody")
end
# Out:
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in4", "id" => "YrXGAj2qAduXaS2KI1x2-13", "parent" => "YrXGAj2qAduXaS2KI1x2-8", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/3ZWy5/src/diagrams/_xml2model.jl:76
# v_z_carbody (generic function with 1 method)

# %%
@model Test_v_z_carbody begin
    @block begin
        p = v_z_carbody()
        ramp1 = Ramp(starttime=10, slope=5)
        ramp2 = Ramp(starttime=10, slope=15)
    end
    @connect begin
        ramp1.out => p.in1
        ramp2.out => p.in2
    end
    @scope begin
        p.in1 => test1
        p.in2 => in2
        p.out1 => out1
    end
end

m = @compile Test_v_z_carbody()
res = simulate(m, tspan=[0, 100])
plot(res)

# %%
@model z_velocity begin
    @parameter begin
        I_ENG2Fr_ENG_mount = 0
        I_ENG2Rr_ENG_mount = -0.4
    end
    @xmlmodel("METI_Vertical_Vibration.drawio", "z_velocity")
end
# Out:
# z_velocity (generic function with 1 method)

# %%
@model Test_z_velocity begin
    @block begin
        p = z_velocity()
        ramp1 = Ramp(starttime=10, slope=5)
        ramp2 = Ramp(starttime=10, slope=15)
    end
    @connect begin
        ramp1.out => p.in1
        ramp2.out => p.in2
    end
    @scope begin
        p.in1 => in1
        p.in2 => in2
        p.out1 => out1
        p.out2 => out2
    end
end

m = @compile TestEng_mnt_f_pnt(d_Fr_ENG_mount=1825.3, k_Fr_ENG_mount=1.3598e+05, z_k_Fr_ENG_mount_ini=0.00036769, voltage1=5, voltage2=10)
result = simulate(m, tspan=(0.0, 60.0));
plot(result, layout=(2,2))

# %%
###ここから　ブロック群を作成する 動画と違う

# %%
@buildxml "nanndemoiinamae" pitch_rate v_z_carbody z_velocity  #使うモデル群を書き連ねる
##実行したらファイルができる
#->draw.ioでそのファイルをimport
#->ファイル名のブロック群のタブが出てくる、それを用いる
# Out:
# 6393

# %%
@model HM_F_PNT begin
    @xmlmodel("METI_Vertical_Vibration.drawio", "ENG_PNT")
end
# Out:
# HM_F_PNT (generic function with 1 method)

# %%
@model TestHM_F_PNT begin
    @block begin
        m = HM_F_PNT()
        ramp1 = Ramp(starttime=10, slope=5)
        ramp2 = Ramp(starttime=10, slope=15)
    end
    @connect begin
        ramp1.out => m.in1
        ramp2.out => m.in2
    end
    @scope begin
        m.in1 => in1
        m.in2 => in2
        m.out1 => out1
        m.out2 => out2
    end
end

m = @compile TestHM_F_PNT()
res = simulate(m, tspan=[0, 100])
plot(res)

# %%
@model HM_BD_F_PNT begin
    @parameter begin
        M_Fr_body = 44.01
        g = 9.8
    end
    @xmlmodel("METI_Vertical_Vibration.drawio", "HM_BD_F_PNT")
end
# Out:
# HM_BD_F_PNT (generic function with 1 method)

# %%
@model HM_HD_F_PNT begin
    @parameter begin
        M_Fr_head = 27.6
        r_Fr_head = 0.21857
        theta_Fr_head = 1.3251
        k_Fr_head = 1210
        d_Fr_head = 8.17
        I_Fr_head = 1.8
        x_k_Fr_head_ini = -0.011885
        g = 9.8
    end
    @xmlmodel("METI_Vertical_Vibration.drawio", "HM_HD_F_PNT")
end
# Out:
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in4", "id" => "4qhezxlA_y2oAY6RtaBU-110", "parent" => "4qhezxlA_y2oAY6RtaBU-105", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/yTt33/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in4", "id" => "4qhezxlA_y2oAY6RtaBU-25", "parent" => "4qhezxlA_y2oAY6RtaBU-20", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/yTt33/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in3", "id" => "4qhezxlA_y2oAY6RtaBU-24", "parent" => "4qhezxlA_y2oAY6RtaBU-20", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/yTt33/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in3", "id" => "4qhezxlA_y2oAY6RtaBU-109", "parent" => "4qhezxlA_y2oAY6RtaBU-105", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/yTt33/src/diagrams/_xml2model.jl:76
# ┌ Warning: The port Dict{Any, Any}("label" => "<p style=\"line-height: 100%;\"><br></p>", "name" => "in4", "id" => "4qhezxlA_y2oAY6RtaBU-37", "parent" => "4qhezxlA_y2oAY6RtaBU-32", "type" => "inport") has not been used.
# └ @ JuliaMBD.Diagram /root/.julia/packages/JuliaMBD/yTt33/src/diagrams/_xml2model.jl:76
# HM_HD_F_PNT (generic function with 1 method)

# %%
@model TestHM_HD_F_PNT begin
    @block begin
        m = HM_HD_F_PNT()
        s1 = Step(steptime=5, finalvalue=100)
    end
    @connect begin
        s1.out => m.in1
    end
    @scope begin
        m.in1 => in
        m.out1 => out
    end
end

m = @compile_derivative TestHM_HD_F_PNT() #１つでも微分ブロックがあるなら@compile_derivativeを書き足す,この場合はmatlabの結果と異なる場合がある
res = simulate(m, tspan=[0, 10])
plot(res)
